# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagofernandez132007-glitch/PRACTICA-2/blob/main/practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Procesamiento de Reportes de Planta**
# autores: Thiago Fernandez, Francisco Aguero

# %%
import pandas as pd
url="https://raw.githubusercontent.com/thiagofernandez132007-glitch/PRACTICA-2/refs/heads/main/practica_2.csv"
datos1=pd.read_csv(url)

# %% [markdown]
# ## **1.DIAGNOSTICAR**

# %%
datos1.head()
# Out:
#    ID            Datetime  Temperature   Humidity    Pressure  Co2 Gas  PM2.5  \
# 0   0 2019-05-20 19:08:34    23.005257  33.060454  972.784433      626    3.8
# 1   1 2019-05-20 19:08:35    22.989942  33.095483  972.844472      627    3.8
# 2   2 2019-05-20 19:08:36    23.000152  33.080467  972.804446      627    3.8
# 3   3 2019-05-20 19:08:36    22.989942  33.105487  972.732905      626    3.8
# 4   4 2019-05-20 19:08:37    22.995047  33.105482  972.768675      626    3.7
#
#    PM10 Daytime
# 0   8.8   Night
# 1   8.9   Night
# 2   8.9   Night
# 3   8.9   Night
# 4   8.3   Night

# %%
datos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4100 non-null   int64
#  1   Datetime     4100 non-null   object
#  2   Temperature  4100 non-null   float64
#  3   Humidity     4100 non-null   float64
#  4   Pressure     4100 non-null   float64
#  5   Co2 Gas      4100 non-null   int64
#  6   PM2.5        4100 non-null   float64
#  7   PM10         4100 non-null   float64
#  8   Daytime      4100 non-null   object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 288.4+ KB

# %% [markdown]
# ## **2.AJUSTES**

# %%
print(f"cantidad de duplicados antes: {datos1.duplicated().sum()}")
print(f"no tenemos duplicados por lo tanto no hace falta eliminar nada")
datos1['Datetime']=pd.to_datetime(datos1['Datetime'])
datos1.info()
# Out:
# cantidad de duplicados antes: 0
# no tenemos duplicados por lo tanto no hace falta eliminar nada
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4100 entries, 0 to 4099
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4100 non-null   int64
#  1   Datetime     4100 non-null   datetime64[ns]
#  2   Temperature  4100 non-null   float64
#  3   Humidity     4100 non-null   float64
#  4   Pressure     4100 non-null   float64
#  5   Co2 Gas      4100 non-null   int64
#  6   PM2.5        4100 non-null   float64
#  7   PM10         4100 non-null   float64
#  8   Daytime      4100 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 288.4+ KB

# %% [markdown]
# ## **3.ANALISIS DE TIEMPO DE REGISTROS**
